# %%
#!pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\michael\appdata\local\programs\python\python313\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\michael\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\michael\appdata\local\programs\python\python313\lib\site-packages (from xgboost) (1.14.1)
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import the libraries needed
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
import xgboost as xgb
import pandas as pd

# %%
data=pd.read_csv('customer_churn_prediction_dataset.csv')
